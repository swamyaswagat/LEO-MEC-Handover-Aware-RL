# %% [markdown]
# <a href="https://colab.research.google.com/github/swamyaswagat/LEO-MEC-Handover-Aware-RL/blob/main/Phase1_RVT_Orbital_Environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
